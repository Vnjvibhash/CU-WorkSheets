# %% [markdown]
# **Import necessary libraries**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Load the images to be aligned**

# %%
img1 = cv2.imread('/content/gdrive/MyDrive/Data/images/exp4-2.jpg')
img2 = cv2.imread('/content/gdrive/MyDrive/Data/images/exp4-1.jpg')

# %% [markdown]
# **Display the images**

# %%
plt.figure(figsize=(10, 10))
plt.subplot(121)
plt.imshow(img1)
plt.title('Image 1')
plt.subplot(122)
plt.imshow(img2)
plt.title('Image 2')
plt.show()

# %% [markdown]
# **Get human-guided control points**

# %%
from google.colab.patches import cv2_imshow
# Get the number of control points to be selected
num_control_points = 4

# Initialize the control points list
control_points = []

# Create a window to display the image
cv2_imshow(img2)

# Get mouse click coordinates until the user presses the 'q' key
while cv2.waitKey(1) != ord('q'):
    x, y = cv2.getWindowImageRect('Image')[0] + cv2.getMousePosition()

    # Add the control point to the list
    control_points.append((x, y))

    # Draw a circle at the control point location
    cv2.circle(img2, (x, y), 5, (0, 0, 255), -1)

    # Display the updated image
    cv2_imshow(img2)

# Close the window
cv2.destroyAllWindows()

# Print the control points
print(control_points)
# Iterate over the number of control points
# for i in range(num_control_points):
#     # Get the mouse click coordinates
#     x, y = plt.ginput(1)[0]

#     # Add the control point to the list
#     control_points.append((x, y))

# Display the control points on the images
# plt.figure(figsize=(10, 10))
# plt.subplot(121)
# plt.imshow(img1)
# plt.title('Image 1 with control points')
# plt.scatter(control_points[:, 0], control_points[:, 1], c='red', marker='o')
# plt.subplot(122)
# plt.imshow(img2)
# plt.title('Image 2 with control points')
# plt.scatter(control_points[:, 0], control_points[:, 1], c='red', marker='o')
# plt.show()

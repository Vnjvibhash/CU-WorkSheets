# %% [markdown]
# **Import Libraries**

# %%
import cv2 as cv
import skimage.io as io

# %% [markdown]
# **Load Images**

# %%
image1 = cv.imread("/content/gdrive/MyDrive/Data/images/tajmahal.png", cv.IMREAD_GRAYSCALE)
image2 = cv.imread("/content/gdrive/MyDrive/Data/images/tajmahal1.png", cv.IMREAD_GRAYSCALE)

# %% [markdown]
# **Innitialize keypoints detector and descriptor**

# %%
obr = cv.ORB_create()
cv.SIFT_create()
# Out:
# < cv2.SIFT 0x79ff1bf10d10>

# %% [markdown]
# **Detect keypoints detector and descriptors**

# %%
keyPoint1, desc1 = obr.detectAndCompute(image1,None)
keyPoint2, desc2 = obr.detectAndCompute(image2,None)

# %% [markdown]
# **Innitialize Brute Force Matcher**

# %%
bf=cv.BFMatcher_create()

# %% [markdown]
# **Match the Descriptor using Brute Force**

# %%
matches = bf.match(desc1,desc2)

# %% [markdown]
# **Sort the Matches by Distance**

# %%
matches = sorted(matches,key=lambda x: x.distance)

# %% [markdown]
# **Draw top 'n' matches**

# %%
n=20
result = cv.drawMatches(image1,keyPoint1,image2,keyPoint2,matches[:n],None,flags=2)

# %% [markdown]
# **Display Result**

# %%
io.imshow(result)

# %%
import cv2
import numpy as np

# Load the Haar Cascade classifier for car detection (provide the correct path)
car_cascade = cv2.CascadeClassifier('data/HaarCascadeClassifier/car4.xml')

# Initialize video capture
cap = cv2.VideoCapture('videos/stock-footage-generic-electric-car-driving.webm')

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Perform car detection using the Haar Cascade classifier
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(25, 25))

    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)  # Draw a red rectangle around the car

    # Display the frame with detected cars
    cv2.imshow('Car Detection', frame)

    if cv2.waitKey(10) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the Haar Cascade classifier for car detection (provide the correct path)
car_cascade = cv2.CascadeClassifier('data/HaarCascadeClassifier/car4.xml')

# Initialize video capture
# cap = cv2.VideoCapture('videos/stock-footage-generic-electric-car-driving.webm')
cap = cv2.VideoCapture('videos/Green-screen-car.mp4')

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Perform car detection using the Haar Cascade classifier
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=35, minSize=(25, 25))

    # Draw rectangles around detected cars and count them
    num_cars = 0
    for (x, y, w, h) in cars:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)  # Draw a red rectangle around the car
        num_cars += 1

    # Display the number of detected cars in the console
    print(f"Number of cars detected: {num_cars}")

    # Display the frame with detected cars
    cv2.imshow('Car Detection', frame)

    if cv2.waitKey(10) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 1
# Number of cars detected: 0
# Number of cars detected: 1
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 0
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 3
# Number of cars detected: 3
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 4
# Number of cars detected: 3
# Number of cars detected: 3
# Number of cars detected: 4
# Number of cars detected: 5
# Number of cars detected: 7
# Number of cars detected: 5
# Number of cars detected: 6
# Number of cars detected: 6
# Number of cars detected: 6
# Number of cars detected: 5
# Number of cars detected: 6
# Number of cars detected: 6
# Number of cars detected: 6
# Number of cars detected: 6
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 4
# Number of cars detected: 2
# Number of cars detected: 3
# Number of cars detected: 3
# Number of cars detected: 4
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 4
# Number of cars detected: 1
# Number of cars detected: 3
# Number of cars detected: 5
# Number of cars detected: 3
# Number of cars detected: 2
# Number of cars detected: 5
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 4
# Number of cars detected: 4
# Number of cars detected: 4
# Number of cars detected: 4
# Number of cars detected: 3
# Number of cars detected: 3
# Number of cars detected: 3
# Number of cars detected: 6
# Number of cars detected: 4
# Number of cars detected: 3
# Number of cars detected: 4
# Number of cars detected: 4
# Number of cars detected: 5
# Number of cars detected: 6
# Number of cars detected: 5
# Number of cars detected: 4
# Number of cars detected: 3
# Number of cars detected: 3
# Number of cars detected: 5
# Number of cars detected: 6
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 4
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 5
# Number of cars detected: 4
# Number of cars detected: 7
# Number of cars detected: 7
# Number of cars detected: 7
# Number of cars detected: 8
# Number of cars detected: 9
# Number of cars detected: 9
# Number of cars detected: 8
# Number of cars detected: 8
# Number of cars detected: 7
# Number of cars detected: 9
# Number of cars detected: 9
# Number of cars detected: 7
# Number of cars detected: 9
# Number of cars detected: 7
# Number of cars detected: 9
# Number of cars detected: 6
# Number of cars detected: 7
# Number of cars detected: 7
# Number of cars detected: 10
# Number of cars detected: 10
# Number of cars detected: 9
# Number of cars detected: 10
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 3
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 3
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 3
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 3
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 1
# Number of cars detected: 3
# Number of cars detected: 2
# Number of cars detected: 1
# Number of cars detected: 2
